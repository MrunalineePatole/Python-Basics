# %%
import pandas as pd

# %%
#series object from List
a=pd.Series([1,2,3])

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
a=pd.Series([1,2,3],index=['a','b','c'])

# %%
a
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# series object from dictionary

# %%
d={'a':10,'b':20,'c':30}

# %%
s1=pd.Series(d)

# %%
s1
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#Create Student Data Frame

# %%
student=({"Name":["manu","Anu","Ranu"],"Marks":[89,67,88]})

# %%
pd.DataFrame(student)
# Out:
#    Name  Marks
# 0  manu     89
# 1   Anu     67
# 2  Ranu     88

# %%
#Inbuilt data frame function
i=pd.read_csv('iris.csv')

# %%
i.head()

# %%
i
